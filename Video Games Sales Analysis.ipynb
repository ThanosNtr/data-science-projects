# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sd_data = pd.read_csv('Video_Games.csv')

# %%
sd_data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# ...

# %%
sd_data.shape
# Out:
# (16719, 16)

# %%
sd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       7590 non-null   float64
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# ...

# %%
sd_data.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         9129
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %%
sd_data=sd_data.dropna(subset=['Name','Year_of_Release','Genre','Publisher'])
sd_data.isnull().sum()
# Out:
# Name                  0
# Platform              0
# Year_of_Release       0
# Genre                 0
# Publisher             0
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8434
# Critic_Count       8434
# User_Score         8955
# User_Count         8955
# Developer          6512
# Rating             6649
# dtype: int64

# %%
sd_data.describe()
# Out:
#        Year_of_Release      NA_Sales      EU_Sales      JP_Sales  \
# count     16416.000000  16416.000000  16416.000000  16416.000000
# mean       2006.489888      0.264129      0.146034      0.078623
# std           5.881148      0.819028      0.507134      0.311348
# min        1980.000000      0.000000      0.000000      0.000000
# 25%        2003.000000      0.000000      0.000000      0.000000
# 50%        2007.000000      0.080000      0.020000      0.000000
# 75%        2010.000000      0.240000      0.110000      0.040000
# max        2020.000000     41.360000     28.960000     10.220000
#
#         Other_Sales  Global_Sales  Critic_Score  Critic_Count   User_Score  \
# count  16416.000000  16416.000000   7982.000000   7982.000000  7461.000000
# mean       0.047670      0.536708     68.997119     26.440992     7.126900
# std        0.188156      1.559885     13.918755     19.009305     1.498886
# min        0.000000      0.010000     13.000000      3.000000     0.000000
# ...

# %%
corr_mat=sd_data.corr()
plt.figure(figsize=(12,6))
plt.title('Video Games Heatmap')
sns.heatmap(corr_mat,vmax=.8,square=True)
# Out:
# <AxesSubplot:title={'center':'Video Games Heatmap'}>

# %%
sd_data[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']].describe()
# Out:
#            NA_Sales      EU_Sales      JP_Sales   Other_Sales
# count  16416.000000  16416.000000  16416.000000  16416.000000
# mean       0.264129      0.146034      0.078623      0.047670
# std        0.819028      0.507134      0.311348      0.188156
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        0.080000      0.020000      0.000000      0.010000
# 75%        0.240000      0.110000      0.040000      0.030000
# max       41.360000     28.960000     10.220000     10.570000

# %%
sd_data['Global_Sales'].describe()
# Out:
# count    16416.000000
# mean         0.536708
# std          1.559885
# min          0.010000
# 25%          0.060000
# 50%          0.170000
# 75%          0.470000
# max         82.530000
# Name: Global_Sales, dtype: float64

# %%
plt.figure(figsize=(18,6))
plt.title('Histogram of Video Games Sales')
sns.histplot(data=sd_data['Global_Sales'],binwidth=0.01)
plt.ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
sd_data.sort_values('Global_Sales', ascending=False)[:10]
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %%
plt.figure(figsize=(18,6))
plt.title('Histogram of video games sales less than 10 mill')
sns.histplot(data=sd_data['Global_Sales'], binwidth=0.05, binrange=[0,10])
plt.ylabel("")
# Out:
# Text(0, 0.5, '')

# %%
sd_data['Global_Sales'].skew()
# Out:
# 17.28599301527773

# %%
sd_data['Global_Sales'].kurt()
# Out:
# 596.4311261407373

# %%
sd_data.Platform.value_counts().index.sort_values()
# Out:
# Index(['2600', '3DO', '3DS', 'DC', 'DS', 'GB', 'GBA', 'GC', 'GEN', 'GG', 'N64',
#        'NES', 'NG', 'PC', 'PCFX', 'PS', 'PS2', 'PS3', 'PS4', 'PSP', 'PSV',
#        'SAT', 'SCD', 'SNES', 'TG16', 'WS', 'Wii', 'WiiU', 'X360', 'XB',
#        'XOne'],
#       dtype='object')

# %%
sd_data.loc[sd_data.Platform =='PC'].sort_values('Year_of_Release').head()
# Out:
#                 Name Platform  Year_of_Release       Genre  \
# 14472      Alter Ego       PC           1985.0  Simulation
# 14623        SimCity       PC           1988.0  Simulation
# 769     SimCity 2000       PC           1992.0  Simulation
# 14612           Doom       PC           1992.0     Shooter
# 2612   The 7th Guest       PC           1992.0   Adventure
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 14472          Activision      0.00      0.03       0.0         0.01
# 14623               Maxis      0.00      0.02       0.0         0.01
# 769                 Maxis      1.20      0.84       0.0         0.10
# 14612         id Software      0.02      0.00       0.0         0.00
# 2612   Virgin Interactive      0.02      0.77       0.0         0.00
#
#        Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count  \
# 14472          0.03          59.0           9.0         5.8        19.0
# ...

# %%
plt.figure(figsize=(12,6))
plt.title('Count of Video Games by Platform')
sns.countplot(y='Platform', data=sd_data, order=sd_data.Platform.value_counts().index)
# Out:
# <AxesSubplot:title={'center':'Count of Video Games by Platform'}, xlabel='count', ylabel='Platform'>

# %%
sd_data.groupby('Platform')['Global_Sales'].describe().reset_index()
# Out:
#    Platform   count      mean       std   min     25%    50%     75%    max
# 0      2600   116.0  0.746293  0.955571  0.07  0.3050  0.475  0.7800   7.81
# 1       3DO     3.0  0.033333  0.023094  0.02  0.0200  0.020  0.0400   0.06
# 2       3DS   512.0  0.503750  1.441374  0.01  0.0500  0.120  0.3400  14.60
# 3        DC    52.0  0.307115  0.469912  0.02  0.0775  0.135  0.2975   2.42
# 4        DS  2122.0  0.378761  1.435772  0.01  0.0500  0.110  0.2700  29.80
# 5        GB    97.0  2.622887  5.390733  0.06  0.3000  1.180  2.1800  31.37
# 6       GBA   786.0  0.388830  0.912071  0.01  0.0600  0.160  0.3900  15.85
# 7        GC   542.0  0.363727  0.693107  0.01  0.0700  0.150  0.3700   7.07
# 8       GEN    27.0  1.050370  1.492217  0.03  0.0700  0.150  1.7100   6.03
# 9        GG     1.0  0.040000       NaN  0.04  0.0400  0.040  0.0400   0.04
# 10      N64   316.0  0.690538  1.321415  0.01  0.1300  0.270  0.6000  11.89
# ...

# %%
plt.figure(figsize=(12,8))
plt.title('Total Global Sales of Video Games by PLatform')
sns.barplot(data=sd_data.groupby('Platform', as_index=False).sum(), x='Global_Sales', y='Platform',order=sd_data.groupby('Platform', as_index=False).sum().sort_values('Global_Sales', ascending=False).Platform)
# Out:
# <AxesSubplot:title={'center':'Total Global Sales of Video Games by PLatform'}, xlabel='Global_Sales', ylabel='Platform'>

# %%
plt.figure(figsize=(18,6))
plt.title('Boxplot of global sales by platform')
sns.boxplot(data=sd_data,y='Global_Sales',x='Platform')
# Out:
# <AxesSubplot:title={'center':'Boxplot of global sales by platform'}, xlabel='Platform', ylabel='Global_Sales'>

# %%
plt.figure(figsize=(18,6))
plt.title("Global Sales of Video Games by Platform that sold less than 10 million USD")
sns.boxplot(data=sd_data[sd_data.Global_Sales <= 10],y='Global_Sales', x="Platform", order=sd_data.groupby('Platform', sort=False)['Global_Sales'].max().index)
# Out:
# <AxesSubplot:title={'center':'Global Sales of Video Games by Platform that sold less than 10 million USD'}, xlabel='Platform', ylabel='Global_Sales'>

# %%
multiplatform_titles=sd_data[sd_data.Name.duplicated(keep=False)]
multiplatform_titles.Name.value_counts()
# Out:
# Need for Speed: Most Wanted    12
# LEGO Marvel Super Heroes        9
# Ratatouille                     9
# FIFA 14                         9
# Terraria                        8
#                                ..
# Cool Boarders 2001              2
# Quake II                        2
# The Suffering                   2
# High Rollers Casino             2
# Akatsuki no Goei Trinity        2
# Name: Name, Length: 2749, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('SALES OF NEED FOR SPEED MOST WANTED BY PLATFORM')
sns.barplot(data=sd_data[sd_data.Name=='Need for Speed: Most Wanted'],x='Global_Sales',y='Platform')
# Out:
# <AxesSubplot:title={'center':'SALES OF NEED FOR SPEED MOST WANTED BY PLATFORM'}, xlabel='Global_Sales', ylabel='Platform'>

# %%
plt.figure(figsize=(12,6))
plt.title('Sales of terraria by platform')
sns.barplot(data=sd_data[sd_data.Name=='Terraria'],x='Global_Sales',y='Platform')
# Out:
# <AxesSubplot:title={'center':'Sales of terraria by platform'}, xlabel='Global_Sales', ylabel='Platform'>

# %%
plt.figure(figsize=(12,6))
plt.title('Sale sof Ratatouille by platform')
sns.barplot(data=sd_data[sd_data.Name=='Ratatouille'], x='Global_Sales',y='Platform')
# Out:
# <AxesSubplot:title={'center':'Sale sof Ratatouille by platform'}, xlabel='Global_Sales', ylabel='Platform'>

# %%
multiplatform_and_total_sales = pd.concat([multiplatform_titles.groupby('Platform').mean().loc[:, 'Global_Sales'], sd_data.groupby('Platform').mean().loc[:, 'Global_Sales']], axis = 1)
multiplatform_and_total_sales_data = multiplatform_and_total_sales.reset_index()
multiplatform_and_total_sales_data.columns = ["Platform" ,"Multiplatform Sales", "Total Sales"]
multiplatform_and_total_sales_data = pd.melt(multiplatform_and_total_sales_data, id_vars=['Platform'])
multiplatform_and_total_sales_data.columns = ["Platform", "Multiplatform_or_Total", "Global_Sales"]
multiplatform_and_total_sales_data
# Out:
#    Platform Multiplatform_or_Total  Global_Sales
# 0      2600    Multiplatform Sales      1.786250
# 1       3DS    Multiplatform Sales      0.355745
# 2        DC    Multiplatform Sales      0.330000
# 3        DS    Multiplatform Sales      0.362147
# 4        GB    Multiplatform Sales      3.300526
# ..      ...                    ...           ...
# 57      3DO            Total Sales      0.033333
# 58       GG            Total Sales      0.040000
# 59     PCFX            Total Sales      0.030000
# 60      SCD            Total Sales      0.311667
# 61     TG16            Total Sales      0.080000
#
# [62 rows x 3 columns]

# %%
plt.figure(figsize=(12,12))
plt.title('Mean Sales for Multiplatform and Total Video Games by Platform')
sns.barplot(data=multiplatform_and_total_sales_data, x='Global_Sales', y='Platform', hue='Multiplatform_or_Total', order=sd_data.groupby("Platform").mean().sort_values("Global_Sales", ascending=False).index)
# Out:
# <AxesSubplot:title={'center':'Mean Sales for Multiplatform and Total Video Games by Platform'}, xlabel='Global_Sales', ylabel='Platform'>

# %%
sd_data.Genre.value_counts()
# Out:
# Action          3307
# Sports          2306
# Misc            1697
# Role-Playing    1483
# Shooter         1296
# Adventure       1291
# Racing          1225
# Platform         878
# Simulation       855
# Fighting         837
# Strategy         672
# Puzzle           569
# Name: Genre, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.title('Number of Video Games by Genre')
sns.countplot(data=sd_data,y='Genre',order=sd_data.Genre.value_counts().index)
# Out:
# <AxesSubplot:title={'center':'Number of Video Games by Genre'}, xlabel='count', ylabel='Genre'>

# %%
top_hundrend_data=sd_data.sort_values('Global_Sales', ascending=False)[:100]
plt.figure(figsize=(12,6))
plt.title=('Counts of Video Games by Genre Top 100')
sns.countplot(data=top_hundrend_data,y='Genre', order=top_hundrend_data.Genre.value_counts().index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Genre'>

# %%
plt.figure(figsize=(12,6))
plt.title=("Total Global Sales of Video Games by Genre")
sns.barplot(data=sd_data.groupby('Genre', as_index=False).sum(), x='Global_Sales', y='Genre', order=sd_data.groupby('Genre', as_index=False).sum().sort_values('Global_Sales', ascending=False).Genre)
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Genre'>

# %%
plt.figure(figsize=(18,6))
plt.title=('Total Global Sales by Genre')
sns.boxplot(data=sd_data, x='Global_Sales',y='Genre')
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Genre'>

# %%
plt.figure(figsize=(12,12))
plt.title=('Video Games Sales by Genre less than 10 mill')
sns.boxplot(data=sd_data[sd_data.Global_Sales <= 10], y='Global_Sales', x='Genre',order=sd_data.groupby('Genre', sort=False)['Global_Sales'].max().index)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='Global_Sales'>

# %%
plt.figure(figsize=(12,6))
plt.title=('Mean Global Sales of Video Games by Genre')
sns.barplot(data=sd_data.groupby('Genre', as_index=False).mean(), x='Global_Sales',y='Genre')
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Genre'>

# %%
global_sales_genre_platform = sd_data.pivot_table(index='Genre', columns='Platform', values='Global_Sales', aggfunc=np.sum).dropna(axis=1, thresh=9)
global_sales_mean_genre_platform = sd_data.pivot_table(index='Genre', columns='Platform', values='Global_Sales', aggfunc=np.mean).dropna(axis=1, thresh=9)

# %%
plt.figure(figsize=(24,8))
plt.title=("Heatmap of Genre and Platform with Total Sales")

sns.heatmap(data=global_sales_genre_platform, annot=True, fmt=".3g")
# Out:
# <AxesSubplot:xlabel='Platform', ylabel='Genre'>

# %%
plt.figure(figsize=(24,8))
plt.title=("Heatmap of Genre and Platform with Mean Sales")

sns.heatmap(data=global_sales_mean_genre_platform, annot=True, fmt=".3g")
# Out:
# <AxesSubplot:xlabel='Platform', ylabel='Genre'>

# %%
sd_data.Rating.value_counts()
# Out:
# E       3921
# T       2904
# M       1536
# E10+    1393
# EC         8
# K-A        3
# AO         1
# RP         1
# Name: Rating, dtype: int64

# %%
sd_data.replace(['K-A', 'EC'], 'E', True)

# %%
sd_data.loc[sd_data.Rating == 'RP']
# Out:
#                           Name Platform  Year_of_Release     Genre  \
# 14272  Supreme Ruler: Cold War       PC           2011.0  Strategy
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 14272  Paradox Interactive       0.0      0.03       0.0         0.01
#
#        Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count  \
# 14272          0.03          63.0          12.0         6.8        27.0
#
#                 Developer Rating
# 14272  BattleGoat Studios     RP

# %%
sd_data.loc[14272,'Rating'] = 'E10+'

# %%
sd_data.loc[sd_data.Rating == "AO"]
# Out:
#                               Name Platform  Year_of_Release   Genre  \
# 875  Grand Theft Auto: San Andreas       XB           2005.0  Action
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 875  Take-Two Interactive      1.26      0.61       0.0         0.09
#
#      Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count  \
# 875          1.95          93.0          58.0         8.6       118.0
#
#           Developer Rating
# 875  Rockstar North     AO

# %%
sd_data.loc[sd_data.Name == 'Grand Theft Auto: San Andreas']
# Out:
#                                 Name Platform  Year_of_Release   Genre  \
# 17     Grand Theft Auto: San Andreas      PS2           2004.0  Action
# 875    Grand Theft Auto: San Andreas       XB           2005.0  Action
# 2115   Grand Theft Auto: San Andreas       PC           2005.0  Action
# 10312  Grand Theft Auto: San Andreas     X360           2008.0  Action
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 17     Take-Two Interactive      9.43      0.40      0.41        10.57
# 875    Take-Two Interactive      1.26      0.61      0.00         0.09
# 2115   Take-Two Interactive      0.00      0.93      0.00         0.04
# 10312  Take-Two Interactive      0.08      0.02      0.00         0.01
#
#        Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count  \
# 17            20.81          95.0          80.0         9.0      1588.0
# 875            1.95          93.0          58.0         8.6       118.0
# ...

# %%
sd_data.loc[875,'Rating']='M'

# %%
rating_order=['E','E10+','T','M']
plt.figure(figsize=(12,6))
plt.title=('Count of Video Games Ratings')
sns.countplot(data=sd_data,y=sd_data.Rating,order=rating_order)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Rating'>

# %%
plt.figure(figsize=(12,6))
plt.title=('How Rating Affects Global Sales')
sns.countplot(data=sd_data.sort_values('Global_Sales', ascending=False)[:100],y='Rating',order=rating_order)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Rating'>

# %%
plt.figure(figsize=(12,6))
plt.title=('Sales per Rating')
sns.barplot(data=sd_data.groupby('Rating',as_index=False).sum(), x='Global_Sales',y='Rating',order=rating_order)
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Rating'>

# %%
plt.figure(figsize=(12,6))
plt.title=('MEAN SALES BY RATING')
sns.barplot(data=sd_data.groupby('Rating',as_index=False).mean(),x='Global_Sales',y='Rating',order=rating_order)
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Rating'>

# %%
global_sales_rating_platform = sd_data.pivot_table(index='Rating', columns='Platform', values='Global_Sales', aggfunc=np.sum)
global_sales_mean_rating_platform = sd_data.pivot_table(index='Rating', columns='Platform', values='Global_Sales', aggfunc=np.mean)

global_sales_rating_platform.index = pd.CategoricalIndex(global_sales_rating_platform.index, categories=rating_order)
global_sales_rating_platform.sort_index(level=0, inplace=True)

global_sales_mean_rating_platform.index = pd.CategoricalIndex(global_sales_mean_rating_platform.index, categories=rating_order)
global_sales_mean_rating_platform.sort_index(level=0, inplace=True)

# %%
fig, axes_rating_platform_heatmap = plt.subplots(1, 2, figsize=(16,8))

axes_rating_platform_heatmap[0].set_title("Heatmap Platform and Genre")
sns.heatmap(data=global_sales_rating_platform.transpose(), ax=axes_rating_platform_heatmap[0], annot=True, fmt=".3g")

axes_rating_platform_heatmap[1].set_title("Heatmap Platform and Genre Mean")
sns.heatmap(data=global_sales_mean_rating_platform.transpose(), ax=axes_rating_platform_heatmap[1], annot=True, fmt=".3g")
# Out:
# <AxesSubplot:title={'center':'Heatmap Platform and Genre Mean'}, xlabel='Rating', ylabel='Platform'>

# %%
plt.figure(figsize=(12,6))
plt.title=('Count plot of genre and rating')
sns.countplot(data=sd_data,x='Genre',hue='Rating', order=sorted(sd_data.Genre.dropna().unique()), hue_order=rating_order)
# Out:
# <AxesSubplot:xlabel='Genre', ylabel='count'>

# %%
sd_data.Developer.value_counts()
# Out:
# Ubisoft                      201
# EA Sports                    169
# EA Canada                    164
# Konami                       158
# Capcom                       137
#                             ...
# Zombie                         1
# Le Cortex                      1
# Hypnos                         1
# Genki, Kojima Productions      1
# Interchannel-Holon             1
# Name: Developer, Length: 1680, dtype: int64

# %%
sum(sd_data.Developer.value_counts()==1)
# Out:
# 645

# %%
sum(sd_data.Developer.value_counts() <= 3)
# Out:
# 1092

# %%
sum(sd_data.Developer.value_counts()> 10)
# Out:
# 209

# %%
plt.figure(figsize=(12,6))
plt.title=('Count of Video Games by Developers')
sns.countplot(y='Developer',data=sd_data,order=sd_data.Developer.value_counts().iloc[:20].index)
# Out:
# <AxesSubplot:xlabel='count', ylabel='Developer'>

# %%
top_developers_data = sd_data.groupby("Developer", as_index=False).sum().sort_values('Global_Sales', ascending=False)[:20]

# %%
plt.figure(figsize=(18,8))
plt.title=('Top 20 Global Sales Developers')
sns.barplot(data=top_developers_data, x='Global_Sales',y='Developer')
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Developer'>

# %%
plt.figure(figsize=(18,8))
plt.title=("Top 20 Total Global Sales by Developer")
sns.boxplot(data=sd_data[sd_data['Developer'].isin(top_developers_data['Developer'].values)] , x='Global_Sales', y='Developer', order=top_developers_data['Developer'])
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Developer'>

# %%
sd_data.dropna().loc[sd_data.Developer.str.contains(r"\b(?:EA|Electronic Arts)\b",case=False , regex=True).dropna()].Global_Sales.sum()
# Out:
# 590.33

# %%
sd_data.dropna().loc[sd_data.Developer.str.contains(r'\b(?:Nintendo)\b',case=False, regex=True).dropna()].Global_Sales.sum()
# Out:
# 551.57

# %%
sd_developer_counts = sd_data.Developer.value_counts()
frequent_developers_data = sd_data.loc[sd_data.Developer.isin(sd_developer_counts.index[sd_developer_counts.gt(5)])]

# %%
plt.figure(figsize=(18,8))
plt.title=("Top 20 Mean Global Sales by Developer")
sns.barplot(data=frequent_developers_data.groupby("Developer", as_index=False).mean().sort_values('Global_Sales', ascending=False)[:20] , x='Global_Sales', y='Developer')
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Developer'>

# %%
high_mean_developers = frequent_developers_data.groupby("Developer", as_index=False).mean().sort_values('Global_Sales', ascending=False)[:20].Developer
sd_data.loc[sd_data.Developer.isin(high_mean_developers)].Rating.value_counts()
# Out:
# M       106
# T       106
# E        92
# E10+     19
# Name: Rating, dtype: int64

# %%
sd_data.loc[sd_data.Developer=='Nintendo'].Rating.value_counts()
# Out:
# E       58
# E10+    10
# T        4
# Name: Rating, dtype: int64

# %%
sd_data.Critic_Score.describe()
# Out:
# count    7982.000000
# mean       68.997119
# std        13.918755
# min        13.000000
# 25%        60.000000
# 50%        71.000000
# 75%        79.000000
# max        98.000000
# Name: Critic_Score, dtype: float64

# %%
sd_data.User_Score.describe()
# Out:
# count    7461.000000
# mean        7.126900
# std         1.498886
# min         0.000000
# 25%         6.400000
# 50%         7.500000
# 75%         8.200000
# max         9.700000
# Name: User_Score, dtype: float64

# %%
plt.figure(figsize=(20,8))
plt.title=('Graph of Critic Score')
critic_score_count=sns.countplot(data=sd_data, x=sd_data.Critic_Score, order = range(0,100))
critic_score_count.set_xticks(range(0,100,10))

# %%
plt.figure(figsize=(20,8))
plt.title=("Graph of User Score")
user_score_count = sns.countplot(data=sd_data, x=sd_data.User_Score, order = [x/10 for x in range(0,100)])
user_score_count.set_xticks(range(0,100,10))

# %%
fig, axes_score_scatter = plt.subplots(1, 2, figsize=(24,10))

axes_score_scatter[0].set_title("Scatter graph of Crtiics and Global Sales")
sns.scatterplot(data=sd_data, x='Critic_Score', y='Global_Sales', ax=axes_score_scatter[0])

axes_score_scatter[1].set_title("Scatter graph of Users and Global Sales")
sns.scatterplot(data=sd_data, x='User_Score', y='Global_Sales', ax=axes_score_scatter[1])
# Out:
# <AxesSubplot:title={'center':'Scatter graph of Users and Global Sales'}, xlabel='User_Score', ylabel='Global_Sales'>

# %%
fig, axes_score_scatter_limited = plt.subplots(1, 2, figsize=(24,10))

axes_score_scatter_limited[0].set_title("Scatter graph of Crtiics and Global Sales")
sns.scatterplot(data=sd_data[sd_data.Global_Sales <= 10], x='Critic_Score', y='Global_Sales', ax=axes_score_scatter_limited[0])

axes_score_scatter_limited[1].set_title("Scatter graph of Users and Global Sales")
sns.scatterplot(data=sd_data[sd_data.Global_Sales <= 10], x='User_Score', y='Global_Sales', ax=axes_score_scatter_limited[1])
# Out:
# <AxesSubplot:title={'center':'Scatter graph of Users and Global Sales'}, xlabel='User_Score', ylabel='Global_Sales'>

# %%
fig, axes_score_genre = plt.subplots(1, 2, figsize=(24,10))

sns.boxplot(data=sd_data[sd_data.Global_Sales <= 10], y='Genre', x='Critic_Score', order=sorted(sd_data.Genre.dropna().unique()), ax=axes_score_genre[0])
axes_score_genre[0].set_title("Sales of Video Games by Genre that sold less than 10 million globaly")

axes_score_genre[1].set_title("Scatter graph of Users and Global Sales")
sns.boxplot(data=sd_data[sd_data.Global_Sales <= 10], y='Genre', x='User_Score', order=sorted(sd_data.Genre.dropna().unique()), ax=axes_score_genre[1])
# Out:
# <AxesSubplot:title={'center':'Scatter graph of Users and Global Sales'}, xlabel='User_Score', ylabel='Genre'>

# %%
sd_data.Year_of_Release.describe()
# Out:
# count    16416.000000
# mean      2006.489888
# std          5.881148
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2020.000000
# Name: Year_of_Release, dtype: float64

# %%
year_data=sd_data.loc[sd_data.Year_of_Release.notna()]

# %%
plt.figure(figsize=(22,8))
plt.title=('Histogram of Year')
sns.countplot(data=year_data, x=year_data.Year_of_Release.astype(int), order = range(year_data.Year_of_Release.min().astype(int),year_data.Year_of_Release.max().astype(int)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18580/3744039060.py in <module>
#       1 plt.figure(figsize=(22,8))
#       2 plt.title=('Histogram of Year')
# ----> 3 sns.countplot(data=year_data, x=year_data.Year_of_Release.astype(int), order = range(year_data.Year_of_Release.min().astype(int),year_data.Year_of_Release.max().astype(int)))
#
# AttributeError: 'float' object has no attribute 'astype'

# %%
plt.figure(figsize=(22,8))
plt.title=("Global sales by Year")
sns.barplot(x="Year_of_Release",
            y=year_data.groupby("Year_of_Release").Global_Sales.sum(),
            data=year_data,
            order = range(year_data.Year_of_Release.min().astype(int),year_data.Year_of_Release.max().astype(int)),
            ci = None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18580/2917342397.py in <module>
#       4             y=year_data.groupby("Year_of_Release").Global_Sales.sum(),
#       5             data=year_data,
# ----> 6             order = range(year_data.Year_of_Release.min().astype(int),year_data.Year_of_Release.max().astype(int)),
#       7             ci = None)
#
# AttributeError: 'float' object has no attribute 'astype'

# %%
sale_columns = ('NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales')
total_sales_platform = sd_data.groupby('Platform').sum().loc[:,sale_columns].dropna(axis=1, thresh=4)
mean_sales_platform=sd_data.groupby('Platform').mean().loc[:,sale_columns]

fig, axes_platform_heatmap = plt.subplots(2, 1, figsize=(24,10))

axes_platform_heatmap[0].set_title("Total Sales in Each Region by Genre")
sns.heatmap(data=total_sales_platform.transpose(), ax=axes_platform_heatmap[0], annot=True, fmt=".3g")

axes_platform_heatmap[1].set_title("Mean Sales in Each Region by Genre")
sns.heatmap(data=mean_sales_platform.transpose(), ax=axes_platform_heatmap[1], annot=True, fmt=".3f")
# Out:
# <AxesSubplot:title={'center':'Mean Sales in Each Region by Genre'}, xlabel='Platform'>

# %%
total_sales_genre=sd_data.groupby('Genre').sum().loc[:,sale_columns]
mean_sales_genre=sd_data.groupby('Genre').mean().loc[:,sale_columns]


fig, axes_genre_heatmap = plt.subplots(1, 2, figsize=(14,8))

axes_genre_heatmap[0].set_title("Total Sales in Each Region by Genre")
sns.heatmap(data=total_sales_genre, ax=axes_genre_heatmap[0], annot=True, fmt=".3g")

axes_genre_heatmap[1].set_title("Mean Sales in Each Region by Genre")
sns.heatmap(data=mean_sales_genre, ax=axes_genre_heatmap[1], annot=True, fmt=".3g")
# Out:
# <AxesSubplot:title={'center':'Mean Sales in Each Region by Genre'}, ylabel='Genre'>

# %%
plt.figure(figsize=(12,6))
plt.title=("Top 20 selling Video Games")
sns.barplot(x=sd_data.Global_Sales.sort_values(ascending=False)[:20], y=sd_data.sort_values('Global_Sales', ascending=False).Name[:20])
# Out:
# <AxesSubplot:xlabel='Global_Sales', ylabel='Name'>

# %%
fig, axes = plt.subplots(4,1, figsize=(12,24))

axes[0].set_title('NA')
sns.barplot(ax=axes[0],x=sd_data.NA_Sales.sort_values(ascending=False)[:10], y=sd_data.sort_values('NA_Sales', ascending=False).Name[:10])

axes[1].set_title('EU')
sns.barplot(ax=axes[1],x=sd_data.EU_Sales.sort_values(ascending=False)[:10], y=sd_data.sort_values('EU_Sales', ascending=False).Name[:10])

axes[2].set_title('JP')
sns.barplot(ax=axes[2],x=sd_data.JP_Sales.sort_values(ascending=False)[:10], y=sd_data.sort_values('JP_Sales', ascending=False).Name[:10])

axes[3].set_title('Other')
sns.barplot(ax=axes[3],x=sd_data.Other_Sales.sort_values(ascending=False)[:10], y=sd_data.sort_values('Other_Sales', ascending=False).Name[:10])
# Out:
# <AxesSubplot:title={'center':'Other'}, xlabel='Other_Sales', ylabel='Name'>

# %%
NA_platforms = sd_data.sort_values(by='NA_Sales', ascending=False)[:50].Platform.value_counts()
EU_platforms = sd_data.sort_values(by='EU_Sales', ascending=False)[:50].Platform.value_counts()
JP_platforms = sd_data.sort_values(by='JP_Sales', ascending=False)[:50].Platform.value_counts()
other_platforms = sd_data.sort_values(by='Other_Sales', ascending=False)[:50].Platform.value_counts()

total_platforms = pd.concat([NA_platforms, EU_platforms, JP_platforms, other_platforms], axis=1, keys=['NA', 'EU', 'JP', 'Other']).fillna(0)
tot_platforms_order = total_platforms.sum(axis=1).sort_values(ascending=False).index

# %%
top_platforms = total_platforms.melt(ignore_index=False, var_name='Region', value_name='Count')

plt.figure(figsize=(24,6))
plt.title=("Frequency of platforms in top selling games in NA, EU, JP & Other regions")
sns.barplot(y=top_platforms.Count, x=top_platforms.index, hue=top_platforms.Region, order=tot_platforms_order)
# Out:
# <AxesSubplot:ylabel='Count'>
