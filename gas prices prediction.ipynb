# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
labels=['a','b','c']
values=[1,3,5]
bar=plt.bar(labels,values)
plt.figure(figsize=(4,2))

# %%
data=pd.read_csv('gas_prices.csv')

# %%
data.describe()
# Out:
#               Year  Australia     Canada     France    Germany      Italy  \
# count    19.000000  18.000000  19.000000  19.000000  19.000000  19.000000
# mean   1999.000000   2.348889   2.086842   4.407895   4.224737   4.645789
# std       5.627314   0.845931   0.786618   1.167531   1.425749   1.146610
# min    1990.000000   1.630000   1.380000   3.410000   2.650000   3.570000
# 25%    1994.500000   1.780000   1.590000   3.605000   3.370000   3.805000
# 50%    1999.000000   1.955000   1.730000   3.870000   3.530000   4.390000
# 75%    2003.500000   2.587500   2.180000   4.700000   4.915000   4.940000
# max    2008.000000   4.450000   4.080000   7.510000   7.750000   7.630000
#
#            Japan     Mexico  South Korea         UK        USA
# count  19.000000  19.000000    19.000000  19.000000  19.000000
# mean    3.820526   1.781579     3.835789   4.392632   1.592105
# std     0.696615   0.462148     1.226170   1.455170   0.663355
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# ...

# %%
data.isnull()
# Out:
#      Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   False       True   False   False    False  False  False   False
# 1   False      False   False   False    False  False  False   False
# 2   False      False   False   False    False  False  False   False
# 3   False      False   False   False    False  False  False   False
# 4   False      False   False   False    False  False  False   False
# 5   False      False   False   False    False  False  False   False
# 6   False      False   False   False    False  False  False   False
# 7   False      False   False   False    False  False  False   False
# 8   False      False   False   False    False  False  False   False
# 9   False      False   False   False    False  False  False   False
# 10  False      False   False   False    False  False  False   False
# 11  False      False   False   False    False  False  False   False
# 12  False      False   False   False    False  False  False   False
# ...

# %%
data.head()
# Out:
#    Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0  1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1  1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2  1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3  1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4  1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
#
#    South Korea    UK   USA
# 0         2.05  2.82  1.16
# 1         2.49  3.01  1.14
# 2         2.65  3.06  1.13
# 3         2.88  2.84  1.11
# 4         2.87  2.99  1.11

# %%
Year=data['Year']

# %%
Year
# Out:
# 0     1990
# 1     1991
# 2     1992
# 3     1993
# 4     1994
# 5     1995
# 6     1996
# 7     1997
# 8     1998
# 9     1999
# 10    2000
# 11    2001
# 12    2002
# 13    2003
# 14    2004
# 15    2005
# 16    2006
# 17    2007
# 18    2008
# Name: Year, dtype: int64

# %%
plt.title('Gas Prices Over The Years')
print(data)
for country in data:
    if country != 'Year':
        plt.plot(data.Year,data[country], marker = '.')
plt.xlabel('Year')
plt.ylabel('US DOLLARS')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# ...

# %%
data.columns
# Out:
# Index(['Year', 'Australia', 'Canada', 'France', 'Germany', 'Italy', 'Japan',
#        'Mexico', 'South Korea', 'UK', 'USA'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Year           0
# Australia      1
# Canada         0
# France         0
# Germany        0
# Italy          0
# Japan          0
# Mexico         0
# South Korea    0
# UK             0
# USA            0
# dtype: int64

# %%
country_col=['Australia','France','Italy','Germany','UK','USA','Japan','Canada','Mexico','South Korea']

# %%
data_country=data[country_col]

# %%
data_country.head()
# Out:
#    Australia  France  Italy  Germany    UK   USA  Japan  Canada  Mexico  \
# 0        NaN    3.63   4.59     2.65  2.82  1.16   3.16    1.87    1.00
# 1       1.96    3.45   4.50     2.90  3.01  1.14   3.46    1.92    1.30
# 2       1.89    3.56   4.53     3.27  3.06  1.13   3.58    1.73    1.50
# 3       1.73    3.41   3.68     3.07  2.84  1.11   4.16    1.57    1.56
# 4       1.84    3.59   3.70     3.52  2.99  1.11   4.36    1.45    1.48
#
#    South Korea
# 0         2.05
# 1         2.49
# 2         2.65
# 3         2.88
# 4         2.87

# %%
Year_col=['Year']

# %%
data_Year=data['Year']

# %%
data_Year.describe()
# Out:
# count      19.000000
# mean     1999.000000
# std         5.627314
# min      1990.000000
# 25%      1994.500000
# 50%      1999.000000
# 75%      2003.500000
# max      2008.000000
# Name: Year, dtype: float64

# %%
data_country
# Out:
#     Australia  France  Italy  Germany    UK   USA  Japan  Canada  Mexico  \
# 0         NaN    3.63   4.59     2.65  2.82  1.16   3.16    1.87    1.00
# 1        1.96    3.45   4.50     2.90  3.01  1.14   3.46    1.92    1.30
# 2        1.89    3.56   4.53     3.27  3.06  1.13   3.58    1.73    1.50
# 3        1.73    3.41   3.68     3.07  2.84  1.11   4.16    1.57    1.56
# 4        1.84    3.59   3.70     3.52  2.99  1.11   4.36    1.45    1.48
# 5        1.95    4.26   4.00     3.96  3.21  1.15   4.43    1.53    1.11
# 6        2.12    4.41   4.39     3.94  3.34  1.23   3.64    1.61    1.25
# 7        2.05    4.00   4.07     3.53  3.83  1.23   3.26    1.62    1.47
# 8        1.63    3.87   3.84     3.34  4.06  1.06   2.82    1.38    1.49
# 9        1.72    3.85   3.87     3.42  4.29  1.17   3.27    1.52    1.79
# 10       1.94    3.80   3.77     3.45  4.58  1.51   3.65    1.86    2.01
# 11       1.71    3.51   3.57     3.40  4.13  1.46   3.27    1.72    2.20
# ...
